# %% [markdown]
# # 2026 NFL Draft Big Board
#
# Combined round predictions from all position models (CB, S, LB, Edges, DT). Players are ranked by **predicted round** (1 = first round, 8 = undrafted).
#
# **To refresh predictions:** Run each position's round regression notebook so they save updated CSVs to `data/processed/`:
# - `CB/cb_round_regression.ipynb`
# - `S/s_round_regression.ipynb`
# - `LB/lb_round_regression.ipynb`
# - `Edges/edges_round_regression.ipynb`
# - `DT/dt_round_regression.ipynb`

# %%
import pandas as pd
import os

# Show full dataframe (no row/column truncation)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

DATA = 'data/processed'
pred_files = [
    ('cb_2026_predictions.csv', 'CB'),
    ('s_2026_predictions.csv', 'S'),
    ('lb_2026_predictions.csv', 'LB'),
    ('edges_2026_predictions.csv', 'ED'),
    ('dt_2026_predictions.csv', 'DT'),
    ('ot_2026_predictions.csv', 'OT'),
]

dfs = []
for filename, pos in pred_files:
    path = os.path.join(DATA, filename)
    if os.path.exists(path):
        df = pd.read_csv(path)
        if 'Pos' not in df.columns:
            df['Pos'] = pos
        dfs.append(df)
    else:
        print(f"Missing {path} — run the {pos} round regression notebook to generate it.")

if not dfs:
    raise SystemExit("No prediction files found. Run each position's round_regression notebook first.")

big = pd.concat(dfs, ignore_index=True)
big = big.sort_values(['predicted_round', 'Player']).reset_index(drop=True)
big.insert(0, 'rank', big.index + 1)

# Reorder columns: rank, Player, Pos, School, predicted_round
cols = [c for c in ['rank', 'Player', 'Pos', 'School', 'predicted_round'] if c in big.columns]
big_board = big[cols].copy()
big_board['predicted_round'] = big_board['predicted_round'].astype(float)

print(f"Big board: {len(big_board)} players from {len(dfs)} position groups")
print(f"Predicted rounds: {big_board['predicted_round'].min():.0f} – {big_board['predicted_round'].max():.0f} (8 = undrafted)")
display(big_board)
# Out:
# Big board: 123 players from 5 position groups
# Predicted rounds: 1 – 8 (8 = undrafted)
#      rank                  Player Pos                 School  predicted_round
# 0       1         Rueben Bain Jr.  ED                  Miami         1.015240
# 1       2             Peter Woods  DT                Clemson         1.868741
# 2       3          Mansoor Delane  CB          Virginia Tech         1.943159
# 3       4        DeMonte Capehart  DT                Clemson         2.460996
# 4       5     Darrell Jackson Jr.  DT          Florida State         2.515605
# 5       6              Lee Hunter  DT             Texas Tech         2.549510
# 6       7            David Bailey  ED             Texas Tech         2.561299
# 7       8          Zxavian Harris  DT               Ole Miss         2.644089
# 8       9            Sonny Styles  LB             Ohio State         2.730182
# 9      10          Akheem Mesidor  ED                  Miami         2.933871
# 10     11           Jalon Kilgore   S         South Carolina         3.259566
# 11     12             Isaac Smith   S      Mississippi State         3.447361
# 12     13          Josiah Trotter  LB               Missouri         3.535056
# 13     14          Xavier Nwankpa   S                   Iowa         3.634129
# 14     15          Avieon Terrell  CB                Clemson         3.691317
# 15     16              Zion Young  ED               Missouri         3.695322
# 16     17      A'Mauri Washington  DT                 Oregon         3.744200
# 17     18          Michael Taaffe   S                  Texas         3.807279
# 18     19           Keldric Faulk  ED                 Auburn         3.810266
# 19     20          Bear Alexander  DT                 Oregon         3.814615
# 20     21            Jermod McCoy  CB           Oregon State         3.832851
# 21     22           Max Llewellyn  ED                   Iowa         3.834964
# 22     23                CJ Allen  LB                Georgia         3.886440
# 23     24         Anthony Hill Jr  LB                  Texas         3.895160
# 24     25              Will Heldt  ED                Clemson         3.915495
# 25     26           Chris Johnson  CB        San Diego State         3.931722
# 26     27         Jacob Rodriguez  LB             Texas Tech         3.982548
# 27     28              Clev Lubin  ED             Louisville         4.077936
# 28     29            Arvell Reese  LB             Ohio State         4.125178
# 29     30             Caleb Banks  DT                Florida         4.142734
# 30     31          Treydan Stukes  CB                Arizona         4.158136
# 31     32       Davison Igbinosun  CB               Ole Miss         4.210610
# 32     33           Tacario Davis  CB                Arizona         4.235611
# 33     34      Dani Dennis-Sutton  ED             Penn State         4.257993
# 34     35             T.J. Parker  ED                Clemson         4.315296
# 35     36             A.J. Haulcy   S             New Mexico         4.338132
# 36     37       Bishop Fitzgerald   S   North Carolina State         4.375668
# 37     38           Keionte Scott  CB                 Auburn         4.403506
# 38     39          Keith Abney II  CB          Arizona State         4.421624
# 39     40          Romello Height  ED             Texas Tech         4.497181
# 40     41        Dillon Thieneman   S                 Purdue         4.531202
# 41     42        John Henry Daley  ED                   Utah         4.547587
# 42     43         Jaishawn Barham  LB               Michigan         4.549573
# 43     44             Caleb Downs   S                Alabama         4.574063
# 44     45             Jake Golday  LB             Cincinnati         4.610039
# 45     46             Red Murdock  LB                Buffalo         4.631116
# 46     47          Zakee Wheatley   S             Penn State         4.648265
# 47     48         Christen Miller  DT                Georgia         4.678466
# 48     49           Mikail Kamara  ED                Indiana         4.690726
# 49     50             Zane Durant  DT             Penn State         4.779347
# 50     51              Trey Moore  LB                  Texas         4.786368
# 51     52          R Mason Thomas  ED               Oklahoma         4.792931
# 52     53          Malik Muhammad  CB                  Texas         4.808248
# 53     54         Kayden McDonald  DT             Ohio State         4.819340
# 54     55           Derrick Moore  ED               Michigan         4.833663
# 55     56       Matayo Uiagalelei  ED                 Oregon         4.851844
# 56     57        Malachi Lawrence  ED                    UCF         4.915113
# 57     58          Deontae Lawson  LB                Alabama         4.961789
# 58     59            Taurean York  LB              Texas A&M         4.963100
# 59     60       Harold Perkins Jr  LB                    LSU         4.983731
# 60     61              Kyle Louis  LB             Pittsburgh         4.999239
# 61     62           Jakobe Thomas   S       Middle Tennessee         5.008644
# 62     63         Daylen Everette  CB                Georgia         5.015521
# 63     64           Raylen Wilson  LB                Georgia         5.022440
# 64     65             Devin Moore  CB                Florida         5.059200
# 65     66            Peyton Bowen   S               Oklahoma         5.066827
# 66     67             Colton Hood  CB                 Auburn         5.087809
# 67     68    Kenyatta Jackson Jr.  ED             Ohio State         5.183317
# 68     69              Josh Moten  CB              Texas A&M         5.215790
# 69     70         Bryce Boettcher  LB                 Oregon         5.219100
# 70     71           Gracen Halton  DT               Oklahoma         5.258350
# 71     72           Anthony Lucas  ED                    USC         5.259592
# 72     73          Joshua Josephs  ED              Tennessee         5.284173
# 73     74              Gabe Jacas  ED               Illinois         5.315807
# 74     75       Brandon Cleveland  DT               NC State         5.352123
# 75     76    Jermaine Mathews Jr.  CB             Ohio State         5.376709
# 76     77  Emmanuel McNeil-Warren   S                 Toledo         5.384703
# 77     78           Lander Barton  LB                   Utah         5.407440
# 78     79          Rayshaun Benny  DT               Michigan         5.415737
# 79     80        Domonique Orange  DT             Iowa State         5.417715
# 80     81            Ahmaad Moses   S                    SMU         5.450258
# 81     82          Keanu Tanuvasa  DT                    BYU         5.459245
# 82     83          Cashius Howell  ED              Texas A&M         5.468990
# 83     84         Hezekiah Masses  CB  Florida International         5.469277
# 84     85               Anto Saka  ED           Northwestern         5.484391
# 85     86             Julian Neal  CB           Fresno State         5.485715
# 86     87     Vincent Anthony Jr.  ED                   Duke         5.504858
# 87     88         Isaiah Nwokobia   S                    SMU         5.524939
# 88     89           Genesis Smith   S                Arizona         5.528936
# 89     90            Xavier Scott  CB               Illinois         5.557802
# 90     91           Jalen Catalon   S               Arkansas         5.570275
# 91     92               Bud Clark   S                    TCU         5.627112
# 92     93            Albert Regis  DT              Texas A&M         5.668083
# 93     94            Eric O'Neill  ED                Rutgers         5.693418
# 94     95           Brandon Cisse  CB   North Carolina State         5.702227
# 95     96          Patrick Payton  ED                    LSU         5.722888
# 96     97           Jalen Stroman   S          Virginia Tech         5.731111
# 97     98         Chandler Rivers  CB                   Duke         5.770561
# 98     99  Robert Spears-Jennings   S               Oklahoma         5.869066
# 99    100            Cole Brevard  DT                  Texas         5.929627
# 100   101          D'Angelo Ponds  CB          James Madison         5.946795
# 101   102      Skyler Gill-Howard  DT             Texas Tech         6.014560
# 102   103          Domani Jackson  CB                    USC         6.143133
# 103   104         Kalil Alexander  LB            Texas State         6.204742
# 104   105          Thaddeus Dixon  CB             Washington         6.230230
# 105   106             James Smith  DT                Alabama         6.250643
# 106   107            Will Lee III  CB              Texas A&M         6.268807
# 107   108                Ben Bell  ED          Virginia Tech         6.439531
# 108   109            Arvell Reese  ED             Ohio State         6.539368
# 109   110         Landon Robinson  DT                   Navy         6.579203
# 110   111               C.J. Fite  DT          Arizona State         6.742096
# 111   112         Dontay Corleone  DT             Cincinnati         6.987430
# 112   113          Tim Keenan III  DT                Alabama         7.008160
# 113   114         Keeshawn Silver  DT                    USC         7.147047
# 114   115         Boubacar Traore  ED             Notre Dame         7.179548
# 115   116             Tyreak Sapp  ED                Florida         7.271681
# 116   117         Jaishawn Barham  ED               Michigan         7.282510
# 117   118                  TJ Guy  ED               Michigan         7.481380
# 118   119           Kamari Ramsey   S                   UCLA         7.637037
# 119   120               David Oke  DT               Arkansas         8.000000
# 120   121        George Gumbs Jr.  ED                Florida         8.000000
# 121   122       Suntarine Perkins  ED               Ole Miss         8.000000
# 122   123              Trey Moore  ED                  Texas         8.000000
